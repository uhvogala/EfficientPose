# %%
# %load_ext autoreload

# %autoreload 2

# %%
import debug

debug.main([
    "--phi", "0",
    "--anchors",
    "--annotations",
    "--image-index", "200",
    "--no-color-augmentation",
    "--no-6dof-augmentation",
    "--rotation-representation", "axis_angle",
    "--draw_2d-bboxes",
    "linemod", "/mnt/hgfs/VMShare/preprocessed",
    "--object-id", "42",
])
# Out:
# ['--phi', '0', '--anchors', '--annotations', '--image-index', '200', '--no-color-augmentation', '--no-6dof-augmentation', '--rotation-representation', 'axis_angle', '--draw_2d-bboxes', 'linemod', '/mnt/hgfs/VMShare/preprocessed', '--object-id', '42']
# creating generator
# {'train': True, 'shuffle_groups': False, 'rotation_representation': 'axis_angle', 'use_colorspace_augmentation': False, 'use_6DoF_augmentation': False, 'phi': 0}
# Namespace(anchors=True, annotations=True, dataset_type='linemod', draw_2d_bboxes=True, draw_class_names=False, image_index=200, linemod_path='/mnt/hgfs/VMShare/preprocessed', no_6dof_augmentation=True, no_color_augmentation=True, object_id=42, phi=0, rotation_representation='axis_angle')
# running
# loading image
# loaded image
# Generator idx: 200
# Showing debug image
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F8417049588>

# %%
import evaluate

evaluate.main([
    "--phi", "0",
    "--weights", "weights/phi_0_16-10-1.h5",
    "--validation-image-save-path", "evaluation/16-10-1",
    "linemod", "/mnt/hgfs/VMShare/preprocessed",
    "--object-id", "42",
])
# Out:
# {'dataset_type': 'linemod', 'rotation_representation': 'axis_angle', 'weights': 'weights/phi_0_16-10-1.h5', 'batch_size': 1, 'phi': 0, 'gpu': None, 'score_threshold': 0.5, 'validation_image_save_path': 'evaluation/16-10-1', 'linemod_path': '/mnt/hgfs/VMShare/preprocessed', 'object_id': 42}
#
# Creating the Generators...
# {'train': False, 'shuffle_groups': False, 'rotation_representation': 'axis_angle', 'use_colorspace_augmentation': False, 'use_6DoF_augmentation': False, 'batch_size': 1, 'phi': 0}
# Done!
#
# Building the Model...
# WARNING:tensorflow:From /home/vertti/miniconda3/envs/EfficientPose/lib/python3.7/site-packages/tensorflow_core/python/util/deprecation.py:507: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# ...
