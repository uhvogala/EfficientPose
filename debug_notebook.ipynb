# %%
# %load_ext autoreload

# %autoreload 2

# %%
import debug

debug.main([
    "--phi", "0",
    "--anchors",
    "--annotations",
    "--image-index", "4500",
    "--no-color-augmentation",
    "--no-6dof-augmentation",
    "--rotation-representation", "axis_angle",
    "--draw_2d-bboxes",
    "linemod", "/home/jupyter/blender_proc_microplates/output/preprocessed",
    "--object-id", "42",
])
# Out:
# ['--phi', '0', '--anchors', '--annotations', '--image-index', '4500', '--no-color-augmentation', '--no-6dof-augmentation', '--rotation-representation', 'axis_angle', '--draw_2d-bboxes', 'linemod', '/home/jupyter/blender_proc_microplates/output/preprocessed', '--object-id', '42']
# creating generator
# {'train': True, 'shuffle_groups': False, 'rotation_representation': 'axis_angle', 'use_colorspace_augmentation': False, 'use_6DoF_augmentation': False, 'phi': 0}
# Namespace(anchors=True, annotations=True, dataset_type='linemod', draw_2d_bboxes=True, draw_class_names=False, image_index=4500, linemod_path='/home/jupyter/blender_proc_microplates/output/preprocessed', no_6dof_augmentation=True, no_color_augmentation=True, object_id=42, phi=0, rotation_representation='axis_angle')
# running
# loading image
# loaded image
# Generator idx: 4500
# Showing debug image
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F5872DF35C0>
